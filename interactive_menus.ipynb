# %%
import pandas as pd
import plotly.graph_objects as px

# %%
data = pd.read_csv("spotify_data.csv")
data = data.dropna()
print(data.head(2))
# Out:
#           Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 91  2017-04-07      13042637  6533680.0                 9736931.0  8055220.0
# 92  2017-04-08      12815920  6660608.0                 9334494.0  7280150.0
#
#     Unforgettable
# 91       317011.0
# 92       308838.0

# %%
songs_list = list(data.columns)

# %%
plot = px.Figure(data=[px.Scatter(x=data[songs_list[0]], 
                                  y=data[songs_list[1]])
                    ]
                )

# %%
plot.show()

# %% [markdown]
# Adding Dropdown

# %%
plot.update_layout(
                    updatemenus=[
                    dict(
                        buttons = list([
                            dict(
                                args=["type", "scatter"],
                                label = "Scatter plot of songs",
                                method = "restyle"
                            ),
                            dict(
                                args=["type", "bar"],
                                label = "Bar Chart",
                                method = "restyle"
                            ),
                            dict(
                                args=["type", "box"],
                                label = "Box Plot",
                                method = "restyle"
                            )
                        ]),
                        direction="down",
                    ),
                ],
                xaxis = dict(
                    rangeselector=dict(
                        buttons=list([
                            dict(count=1,
                                 step = "day",
                                 stepmode = "todate"),
                        ])
                    ),
                    rangeslider=dict(
                        visible = True
                    ),
                ),
                legend = dict(
                    
                )
            )


plot.show()
